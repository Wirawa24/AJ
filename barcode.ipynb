# %% [markdown]
# <a href="https://colab.research.google.com/github/Wirawa24/AJ/blob/main/barcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import barcode # type: ignore
from barcode.writer import ImageWriter # type: ignore
from IPython.display import Image, display

def generate_barcode(data):
   code = barcode.get ('code128',data,writer=ImageWriter())
   barcode_filename = code.save ("barcode")
   print ("Barcode generated.")

   display (Image (f"{barcode_filename}"))

   data = "1234-5678-9058"
   generate_barcode(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3613256647.py in <cell line: 0>()
# ----> 1 import barcode # type: ignore
#       2 from barcode.writer import ImageWriter # type: ignore
#       3 from IPython.display import Image, display
#       4
#       5 def generate_barcode(data):
#
# ModuleNotFoundError: No module named 'barcode'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install python-barcode # Installing the missing 'barcode' module.

import barcode # type: ignore
from barcode.writer import ImageWriter # type: ignore
from IPython.display import Image, display

def generate_barcode(data):
   code = barcode.get ('code128',data,writer=ImageWriter())
   barcode_filename = code.save ("barcode")
   print ("Barcode generated.")

   display (Image (f"{barcode_filename}"))

data = "1234-5678-9058"  # Moved outside the function to avoid redundant calls
generate_barcode(data)  # Calling the function to generate the barcode
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 kB 3.8 MB/s eta 0:00:00
# ...
# Barcode generated.
