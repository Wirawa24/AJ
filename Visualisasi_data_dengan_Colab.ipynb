# %% [markdown]
# <a href="https://colab.research.google.com/github/Wirawa24/AJ/blob/main/Visualisasi_data_dengan_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
import numpy as np #library untuk matematika
import pandas as pd #library untuk dataframe
import seaborn as sns #library untuk visualisasi
import matplotlib.pyplot as plt #library untuk visualisasi

# %%
#Load Data
dataset = sns.load_dataset("mpg") #mengload dataset mpg
dataset.head() #melihat data teratas
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['mpg'].plot(kind='hist', bins=20, title='mpg')
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=dataset)
# Out:
# https://docs.google.com/spreadsheets/d/1ZUpukH_YM5o9YPVdxX_ROxDet7Dkzo4BAdgErmMGqz4/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1ZUpukH_YM5o9YPVdxX_ROxDet7Dkzo4BAdgErmMGqz4/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# @title horsepower vs weight
from matplotlib import pyplot as plt
dataset.plot(kind='scatter', x='horsepower', y='weight', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-318258662.py in <cell line: 0>()
#       2 from matplotlib import pyplot as plt
#       3 dataset.plot(kind='scatter', x='horsepower', y='weight', s=32, alpha=.8)
# ----> 4 plt.gca().spines[['top', 'right',]].set_visible(false)
#
# NameError: name 'false' is not defined

# %%
### Mempersiapkan data untuk plot
data_origin = dataset["origin"].value_counts().to_dict()
data_pie = data_origin.values()
label_pie = data_origin.keys()
colors = sns.color_palette('pastel')[0:5]

# %%
plt.pie(x = data_pie,
labels = label_pie,
colors = colors,
autopct='%.0f%%')
plt.title("Origin")
plt.show()

# %%
sns.histplot(data = dataset,
x = "mpg",
bins = 30)
plt.show()

# %%
sns.boxplot(data = dataset,
x = "mpg")
plt.show()

# %%
sns.barplot(data = dataset,
x = "origin",
y = "mpg",
            )
plt.show()

# %%
sns.lineplot(data = dataset,
x = "model_year",
y = "mpg",
hue = "origin")
# Out:
# <Axes: xlabel='model_year', ylabel='mpg'>

# %%
sns.scatterplot(data = dataset,
x = "displacement",
y = "mpg")
# Out:
# <Axes: xlabel='displacement', ylabel='mpg'>
